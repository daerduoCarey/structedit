# %% [markdown]
# ## Show Ground-Truth SynShapes Data

# %%
# %matplotlib notebook

import os
import matplotlib
from data import PartNetDataset
from vis_utils import draw_partnet_objects

matplotlib.pyplot.ion()

data_dir = '../data/synshapesdata/syn_chair'

# read all data
object_names = [item.rstrip() for item in os.listdir(data_dir) if item.endswith('.json')]

# visualize one data
obj_idx = 0
object_name = object_names[obj_idx]

obj = PartNetDataset.load_object(os.path.join(data_dir, object_name))
print(obj)
 
draw_partnet_objects(objects=[obj], object_names=[object_name], 
                     figsize=(10, 5), leafs_only=True, visu_edges=False,
                     sem_colors_filename='../stats/semantics_colors/SynChair.txt')
# Out:
# 0 chair    {14}
#   ├0 chair_back    {1}
#   |  ├0 back_surface    {1}
#   |  |  ├0 back_single_surface [LEAF] {0}
#   ├1 chair_seat [LEAF] {1}
#   ├2 chair_arm    {4}
#   |  ├0 armrest [LEAF] {2}
#   |  ├1 armsupport [LEAF] {3}
#   ├3 chair_arm    {6}
#   |  ├0 armrest [LEAF] {4}
#   |  ├1 armsupport [LEAF] {5}
#   ├4 chair_base    {14}
#   |  ├0 leg [LEAF] {6}
#   |  ├1 leg [LEAF] {7}
#   |  ├2 leg [LEAF] {8}
#   |  ├3 leg [LEAF] {9}
#   |  ├4 bar_stretcher [LEAF] {10}
#   |  ├5 bar_stretcher [LEAF] {11}
#   |  ├6 bar_stretcher [LEAF] {12}
#   |  ├7 bar_stretcher [LEAF] {13}
# <img src="data:image/png;base64,..." width="1000">
